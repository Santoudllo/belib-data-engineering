# %%
import pandas as pd
from pymongo import MongoClient
from urllib.parse import quote_plus
from skimpy import skim

# %%
class BikeDataPipeline:
    def __init__(self):
        self.username = 'santoudllo'
        self.password = '*******'
        self.dbname = 'belib_database'
        self.collection_name = 'belib.collection'
        self.mongodb_uri = f"mongodb+srv://{quote_plus(self.username)}:{quote_plus(self.password)}@bike.kvgkgvj.mongodb.net/{self.dbname}?retryWrites=true&w=majority"

    def fetch_data_from_mongodb(self):
        try:
            client = MongoClient(self.mongodb_uri)
            db = client[self.dbname]
            collection = db[self.collection_name]
            data = list(collection.find({}))  
            return data
        except Exception as e:
            print(f"Erreur lors de la récupération des données depuis MongoDB : {e}")
            return None

# %%
# Créer une instance de la pipeline
pipeline = BikeDataPipeline()
data = pipeline.fetch_data_from_mongodb()

# %%
if data:
    df = pd.DataFrame(data)
    display(df)
    # Enregistrement des données dans un fichier CSV
    csv_path = "/home/santoudllo/Desktop/Projet_perso/belib-data-engineering/belib-pipeline/data/01_raw/belib_data.csv"
    df.to_csv(csv_path, index=False)
    print(f"Données enregistrées dans le fichier CSV : {csv_path}")
else:
    print("Aucune donnée récupérée depuis MongoDB")
# Out:
#                            _id             id_pdc  statut_pdc  \
# 0     66465a52dd6bc39c039ec745  FR*V75*EPX11*05*4  Disponible
# 1     66465a52dd6bc39c039ec746  FR*V75*EPX20*09*2     Inconnu
# 2     66465a52dd6bc39c039ec747  FR*V75*EPX20*09*3     Inconnu
# 3     66465a52dd6bc39c039ec748  FR*V75*E9005*02*1     Inconnu
# 4     66465a52dd6bc39c039ec749  FR*V75*EPX12*04*4     Inconnu
# ...                        ...                ...         ...
# 2124  664870e5c7ace53b266c313b                NaN  En service
# 2125  664870e5c7ace53b266c313c                NaN  En service
# 2126  664870e5c7ace53b266c313d                NaN  En service
# 2127  664870e5c7ace53b266c313e                NaN  En service
# 2128  664870e5c7ace53b266c313f                NaN  En service
#
#                                     url_description_pdc  \
# 0     https://parisdata.opendatasoft.com/explore/dat...
# 1     https://parisdata.opendatasoft.com/explore/dat...
# 2     https://parisdata.opendatasoft.com/explore/dat...
# 3     https://parisdata.opendatasoft.com/explore/dat...
# 4     https://parisdata.opendatasoft.com/explore/dat...
# ...                                                 ...
# 2124                                                NaN
# 2125                                                NaN
# 2126                                                NaN
# 2127                                                NaN
# 2128                                                NaN
#
#                    last_updated                         coordonneesxy  \
# 0     2022-06-13T02:30:01+00:00  {'lon': 2.3664377, 'lat': 48.865765}
# 1     2022-09-23T02:30:02+00:00       {'lon': 2.4092, 'lat': 48.8731}
# 2     2022-09-23T02:30:02+00:00       {'lon': 2.4092, 'lat': 48.8731}
# 3     2022-11-22T03:20:17+00:00     {'lon': 2.35242, 'lat': 48.84477}
# 4     2023-05-24T02:30:05+00:00   {'lon': 2.3922555, 'lat': 48.83641}
# ...                         ...                                   ...
# 2124                        NaN   {'lon': 2.3864658, 'lat': 48.87387}
# 2125                        NaN  {'lon': 2.2558389, 'lat': 48.846973}
# 2126                        NaN  {'lon': 2.2558389, 'lat': 48.846973}
# 2127                        NaN  {'lon': 2.2558389, 'lat': 48.846973}
# 2128                        NaN  {'lon': 2.2558389, 'lat': 48.846973}
#
#                              adresse_station code_insee_commune  \
# 0           8 Boulevard Voltaire 75011 Paris              75111
# 1                6 Rue Guébriant 75020 Paris              75120
# 2                6 Rue Guébriant 75020 Paris              75120
# 3                   55 Rue Monge 75005 Paris              75105
# 4           251 Rue de Charenton 75012 Paris              75112
# ...                                      ...                ...
# 2124        356 Rue des Pyrénées 75020 Paris              75120
# 2125  1-3 Av. du Général Sarrail 75016 Paris              75116
# 2126  1-3 Av. du Général Sarrail 75016 Paris              75116
# 2127  1-3 Av. du Général Sarrail 75016 Paris              75116
# 2128  1-3 Av. du Général Sarrail 75016 Paris              75116
#
#           arrondissement            id_pdc_local  ... puissance_nominale  \
# 0     11e Arrondissement                     NaN  ...                NaN
# 1     20e Arrondissement                     NaN  ...                NaN
# 2     20e Arrondissement                     NaN  ...                NaN
# 3     05e Arrondissement                     NaN  ...                NaN
# 4     12e Arrondissement                     NaN  ...                NaN
# ...                  ...                     ...  ...                ...
# 2124  20e Arrondissement       FR*V75*EPX20*15*4  ...                  7
# 2125  16e Arrondissement  FR*V75*EHBSAE*PDA*04*3  ...                 50
# 2126  16e Arrondissement  FR*V75*EHBSAE*PDA*02*2  ...                 50
# 2127  16e Arrondissement  FR*V75*EHBSAE*PDA*05*1  ...                 43
# 2128  16e Arrondissement  FR*V75*EHBSAE*PDA*03*3  ...                 50
#
#      prise_type_ef prise_type_2 prise_type_combo_ccs prise_type_chademo  \
# 0              NaN          NaN                  NaN                NaN
# 1              NaN          NaN                  NaN                NaN
# 2              NaN          NaN                  NaN                NaN
# 3              NaN          NaN                  NaN                NaN
# 4              NaN          NaN                  NaN                NaN
# ...            ...          ...                  ...                ...
# 2124          True         True                False              False
# 2125         False        False                False               True
# 2126         False        False                 True              False
# 2127         False         True                False              False
# 2128         False        False                False               True
#
#      prise_type_autre prise_type_3         num_pdl horaires raccordement
# 0                 NaN          NaN             NaN      NaN          NaN
# 1                 NaN          NaN             NaN      NaN          NaN
# 2                 NaN          NaN             NaN      NaN          NaN
# 3                 NaN          NaN             NaN      NaN          NaN
# 4                 NaN          NaN             NaN      NaN          NaN
# ...               ...          ...             ...      ...          ...
# 2124            False        False   7243270515296     24/7       Direct
# 2125            False        False  50091256854973     24/7       Direct
# 2126            False        False  50091256854973     24/7       Direct
# 2127            False        False  50091256854973     24/7       Direct
# 2128            False        False  50091256854973     24/7       Direct
#
# [2129 rows x 46 columns]
# Données enregistrées dans le fichier CSV : /home/santoudllo/Desktop/Projet_perso/belib-data-engineering/belib-pipeline/data/01_raw/belib_data.csv

# %%
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 2129   │ │ string      │ 43    │                                                          │
# │ │ Number of columns │ 43     │ └─────────────┴───────┘                                                          │
# │ └───────────────────┴────────┘                                                                                  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                         ┃ NA       ┃ NA %       ┃ words per row           ┃ total words        ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ id_pdc                              │     1909 │      89.67 │                     0.1 │                220 │  │
# │ │ statut_pdc                          │        0 │          0 │                     1.9 │               4038 │  │
# │ │ url_description_pdc                 │     1909 │      89.67 │                     0.1 │                220 │  │
# │ │ last_updated                        │     1909 │      89.67 │                     0.1 │                220 │  │
# │ │ adresse_station                     │        0 │          0 │                     5.8 │              12318 │  │
# │ │ code_insee_commune                  │       15 │        0.7 │                    0.99 │               2114 │  │
# │ │ arrondissement                      │        0 │          0 │                       2 │               4258 │  │
# │ │ id_pdc_local                        │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ id_station_local                    │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ id_station_itinerance               │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ nom_station                         │      220 │      10.33 │                     5.3 │              11339 │  │
# │ │ implantation_station                │      220 │      10.33 │                    0.92 │               1960 │  │
# │ │ nbre_pdc                            │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ date_maj                            │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ condition_acces                     │      220 │      10.33 │                     1.8 │               3818 │  │
# │ │ gratuit                             │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ paiement_acte                       │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ paiement_cb                         │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ paiement_autre                      │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ reservation                         │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ siren_amenageur                     │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ contact_amenageur                   │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ nom_amenageur                       │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ nom_operateur                       │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ contact_operateur                   │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ telephone_operateur                 │      220 │      10.33 │                     4.5 │               9545 │  │
# │ │ nom_enseigne                        │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ tarification                        │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ id_pdc_itinerance                   │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ date_mise_en_service                │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ accessibilite_pmr                   │      220 │      10.33 │                     1.8 │               3863 │  │
# │ │ restriction_gabarit                 │      220 │      10.33 │                     1.8 │               3899 │  │
# │ │ station_deux_roues                  │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ puissance_nominale                  │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ prise_type_ef                       │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ prise_type_2                        │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ prise_type_combo_ccs                │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ prise_type_chademo                  │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ prise_type_autre                    │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ prise_type_3                        │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ num_pdl                             │      220 │      10.33 │                    0.92 │               1954 │  │
# │ │ horaires                            │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ raccordement                        │      220 │      10.33 │                     0.9 │               1909 │  │
# │ └─────────────────────────────────────┴──────────┴────────────┴─────────────────────────┴────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯
