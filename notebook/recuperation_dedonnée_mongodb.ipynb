# %%
import pandas as pd
from pymongo import MongoClient

# %%
class BikeDataPipeline:
    def __init__(self):
        self.username = 'santoudllo'
        self.password = '*****'
        self.dbname = 'belib_database'
        self.collection_name = 'belib.collection'
        self.mongodb_uri = f"mongodb+srv://{quote_plus(self.username)}:{quote_plus(self.password)}@bike.kvgkgvj.mongodb.net/{self.dbname}?retryWrites=true&w=majority"

    def fetch_data_from_mongodb(self):
        try:
            client = MongoClient(self.mongodb_uri)
            db = client[self.dbname]
            collection = db[self.collection_name]
            data = list(collection.find({}))  
            return data
        except Exception as e:
            print(f"Erreur lors de la récupération des données depuis MongoDB : {e}")
            return None

# %%
# Créer une instance de la pipeline
pipeline = BikeDataPipeline()
data = pipeline.fetch_data_from_mongodb()
# Afficher les données sous forme de DataFrame pandas
if data:
    df = pd.DataFrame(data)
    display(df) 
else:
    print("Aucune donnée récupérée depuis MongoDB.")
# Out:
#                           _id             id_pdc  statut_pdc  \
# 0    66465a52dd6bc39c039ec745  FR*V75*EPX11*05*4  Disponible
# 1    66465a52dd6bc39c039ec746  FR*V75*EPX20*09*2     Inconnu
# 2    66465a52dd6bc39c039ec747  FR*V75*EPX20*09*3     Inconnu
# 3    66465a52dd6bc39c039ec748  FR*V75*E9005*02*1     Inconnu
# 4    66465a52dd6bc39c039ec749  FR*V75*EPX12*04*4     Inconnu
# ..                        ...                ...         ...
# 215  66465dd4c11d50b7ac3274c7  FR*V75*EPX13*05*1     Inconnu
# 216  66465dd4c11d50b7ac3274c8  FR*V75*EPX18*11*5     Inconnu
# 217  66465dd4c11d50b7ac3274c9  FR*V75*EPX15*13*5     Inconnu
# 218  66465dd4c11d50b7ac3274ca  FR*V75*EPX15*13*6     Inconnu
# 219  66465dd4c11d50b7ac3274cb  FR*V75*EPX19*17*5     Inconnu
#
#                                    url_description_pdc  \
# 0    https://parisdata.opendatasoft.com/explore/dat...
# 1    https://parisdata.opendatasoft.com/explore/dat...
# 2    https://parisdata.opendatasoft.com/explore/dat...
# 3    https://parisdata.opendatasoft.com/explore/dat...
# 4    https://parisdata.opendatasoft.com/explore/dat...
# ..                                                 ...
# 215  https://parisdata.opendatasoft.com/explore/dat...
# 216  https://parisdata.opendatasoft.com/explore/dat...
# 217  https://parisdata.opendatasoft.com/explore/dat...
# 218  https://parisdata.opendatasoft.com/explore/dat...
# 219  https://parisdata.opendatasoft.com/explore/dat...
#
#                   last_updated                         coordonneesxy  \
# 0    2022-06-13T02:30:01+00:00  {'lon': 2.3664377, 'lat': 48.865765}
# 1    2022-09-23T02:30:02+00:00       {'lon': 2.4092, 'lat': 48.8731}
# 2    2022-09-23T02:30:02+00:00       {'lon': 2.4092, 'lat': 48.8731}
# 3    2022-11-22T03:20:17+00:00     {'lon': 2.35242, 'lat': 48.84477}
# 4    2023-05-24T02:30:05+00:00   {'lon': 2.3922555, 'lat': 48.83641}
# ..                         ...                                   ...
# 215  2023-06-06T02:30:04+00:00    {'lon': 2.356917, 'lat': 48.83039}
# 216  2023-10-19T02:30:06+00:00   {'lon': 2.3375535, 'lat': 48.88508}
# 217  2024-01-03T03:30:06+00:00   {'lon': 2.312675, 'lat': 48.838547}
# 218  2024-01-03T03:30:06+00:00   {'lon': 2.312675, 'lat': 48.838547}
# 219  2024-02-26T03:30:05+00:00   {'lon': 2.370891, 'lat': 48.882175}
#
#                       adresse_station code_insee_commune      arrondissement
# 0    8 Boulevard Voltaire 75011 Paris              75111  11e Arrondissement
# 1         6 Rue Guébriant 75020 Paris              75120  20e Arrondissement
# 2         6 Rue Guébriant 75020 Paris              75120  20e Arrondissement
# 3            55 Rue Monge 75005 Paris              75105  05e Arrondissement
# 4    251 Rue de Charenton 75012 Paris              75112  12e Arrondissement
# ..                                ...                ...                 ...
# 215  188 Avenue de Choisy 75013 Paris              75113  13e Arrondissement
# 216     1bis Rue Ravignan 75018 Paris              75118  18e Arrondissement
# 217       29 Rue Cotentin 75015 Paris              75115  15e Arrondissement
# 218       29 Rue Cotentin 75015 Paris              75115  15e Arrondissement
# 219     4 Avenue Secrétan 75019 Paris              75119  19e Arrondissement
#
# [220 rows x 9 columns]
