# %%
import sys
import pandas as pd

# Ajoutez le dossier contenant bike_data_pipeline.py au chemin de recherche de Python
sys.path.append('../script')
from bike_data_pipeline import BikeDataPipeline

# %%
if data:
    print("Données récupérées depuis MongoDB :")
    
    # Affichez les données avec pandas
    df = pd.DataFrame(data)
    print(df.head())

    # Enregistrez les données en CSV dans un dossier spécifié
    csv_filepath = '../data/01_raw/belib_data.csv'
    df.to_csv(csv_filepath, index=False)
    print(f"Les données ont été enregistrées au format CSV dans '{csv_filepath}'.")
else:
    print("Aucune donnée récupérée.")
# Out:
# Données récupérées depuis MongoDB :
#                         _id             id_pdc  statut_pdc  \
# 0  66465a52dd6bc39c039ec745  FR*V75*EPX11*05*4  Disponible
# 1  66465a52dd6bc39c039ec746  FR*V75*EPX20*09*2     Inconnu
# 2  66465a52dd6bc39c039ec747  FR*V75*EPX20*09*3     Inconnu
# 3  66465a52dd6bc39c039ec748  FR*V75*E9005*02*1     Inconnu
# 4  66465a52dd6bc39c039ec749  FR*V75*EPX12*04*4     Inconnu
#
#                                  url_description_pdc  \
# 0  https://parisdata.opendatasoft.com/explore/dat...
# 1  https://parisdata.opendatasoft.com/explore/dat...
# 2  https://parisdata.opendatasoft.com/explore/dat...
# 3  https://parisdata.opendatasoft.com/explore/dat...
# 4  https://parisdata.opendatasoft.com/explore/dat...
#
#                 last_updated                         coordonneesxy  \
# 0  2022-06-13T02:30:01+00:00  {'lon': 2.3664377, 'lat': 48.865765}
# 1  2022-09-23T02:30:02+00:00       {'lon': 2.4092, 'lat': 48.8731}
# 2  2022-09-23T02:30:02+00:00       {'lon': 2.4092, 'lat': 48.8731}
# 3  2022-11-22T03:20:17+00:00     {'lon': 2.35242, 'lat': 48.84477}
# 4  2023-05-24T02:30:05+00:00   {'lon': 2.3922555, 'lat': 48.83641}
#
#                     adresse_station code_insee_commune      arrondissement  \
# 0  8 Boulevard Voltaire 75011 Paris              75111  11e Arrondissement
# 1       6 Rue Guébriant 75020 Paris              75120  20e Arrondissement
# 2       6 Rue Guébriant 75020 Paris              75120  20e Arrondissement
# 3          55 Rue Monge 75005 Paris              75105  05e Arrondissement
# 4  251 Rue de Charenton 75012 Paris              75112  12e Arrondissement
#
#   id_pdc_local  ... puissance_nominale prise_type_ef prise_type_2  \
# 0          NaN  ...                NaN           NaN          NaN
# 1          NaN  ...                NaN           NaN          NaN
# 2          NaN  ...                NaN           NaN          NaN
# 3          NaN  ...                NaN           NaN          NaN
# 4          NaN  ...                NaN           NaN          NaN
#
#   prise_type_combo_ccs prise_type_chademo prise_type_autre prise_type_3  \
# 0                  NaN                NaN              NaN          NaN
# 1                  NaN                NaN              NaN          NaN
# 2                  NaN                NaN              NaN          NaN
# 3                  NaN                NaN              NaN          NaN
# 4                  NaN                NaN              NaN          NaN
#
#   num_pdl horaires raccordement
# 0     NaN      NaN          NaN
# 1     NaN      NaN          NaN
# 2     NaN      NaN          NaN
# 3     NaN      NaN          NaN
# 4     NaN      NaN          NaN
#
# [5 rows x 46 columns]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[18], line 10
#       8     # Enregistrez les données en CSV dans un dossier spécifié
#       9     csv_filepath = 'data/01_raw/belib_data.csv'
# ---> 10     df.to_csv(csv_filepath, index=False)
#      11     print(f"Les données ont été enregistrées au format CSV dans '{csv_filepath}'.")
#      12 else:
#
# File ~/Desktop/Projet_perso/belib-data-engineering/BeliEnv/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Desktop/Projet_perso/belib-data-engineering/BeliEnv/lib/python3.10/site-packages/pandas/core/generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~/Desktop/Projet_perso/belib-data-engineering/BeliEnv/lib/python3.10/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/Desktop/Projet_perso/belib-data-engineering/BeliEnv/lib/python3.10/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~/Desktop/Projet_perso/belib-data-engineering/BeliEnv/lib/python3.10/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/Desktop/Projet_perso/belib-data-engineering/BeliEnv/lib/python3.10/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'data/01_raw'

# %%
from skimpy import skim
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 2129   │ │ string      │ 43    │                                                          │
# │ │ Number of columns │ 43     │ └─────────────┴───────┘                                                          │
# │ └───────────────────┴────────┘                                                                                  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                         ┃ NA       ┃ NA %       ┃ words per row           ┃ total words        ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ id_pdc                              │     1909 │      89.67 │                     0.1 │                220 │  │
# │ │ statut_pdc                          │        0 │          0 │                     1.9 │               4038 │  │
# │ │ url_description_pdc                 │     1909 │      89.67 │                     0.1 │                220 │  │
# │ │ last_updated                        │     1909 │      89.67 │                     0.1 │                220 │  │
# │ │ adresse_station                     │        0 │          0 │                     5.8 │              12318 │  │
# │ │ code_insee_commune                  │       15 │        0.7 │                    0.99 │               2114 │  │
# │ │ arrondissement                      │        0 │          0 │                       2 │               4258 │  │
# │ │ id_pdc_local                        │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ id_station_local                    │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ id_station_itinerance               │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ nom_station                         │      220 │      10.33 │                     5.3 │              11339 │  │
# │ │ implantation_station                │      220 │      10.33 │                    0.92 │               1960 │  │
# │ │ nbre_pdc                            │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ date_maj                            │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ condition_acces                     │      220 │      10.33 │                     1.8 │               3818 │  │
# │ │ gratuit                             │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ paiement_acte                       │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ paiement_cb                         │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ paiement_autre                      │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ reservation                         │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ siren_amenageur                     │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ contact_amenageur                   │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ nom_amenageur                       │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ nom_operateur                       │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ contact_operateur                   │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ telephone_operateur                 │      220 │      10.33 │                     4.5 │               9545 │  │
# │ │ nom_enseigne                        │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ tarification                        │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ id_pdc_itinerance                   │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ date_mise_en_service                │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ accessibilite_pmr                   │      220 │      10.33 │                     1.8 │               3863 │  │
# │ │ restriction_gabarit                 │      220 │      10.33 │                     1.8 │               3899 │  │
# │ │ station_deux_roues                  │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ puissance_nominale                  │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ prise_type_ef                       │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ prise_type_2                        │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ prise_type_combo_ccs                │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ prise_type_chademo                  │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ prise_type_autre                    │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ prise_type_3                        │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ num_pdl                             │      220 │      10.33 │                    0.92 │               1954 │  │
# │ │ horaires                            │      220 │      10.33 │                     0.9 │               1909 │  │
# │ │ raccordement                        │      220 │      10.33 │                     0.9 │               1909 │  │
# │ └─────────────────────────────────────┴──────────┴────────────┴─────────────────────────┴────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯
